# %%
Bank = ['AMRB','BAC','BK','BMO','BNS','BOCH','BXS','CBAN','CM','COLB','DB','FRC','FVCB','HDB','INDB'
        ,'LYG','MTB','NCBS','OZK','RY','SBNY','TD','UCBI','ALTA','BCBP','BCS','BSAC','BSBR','C'
        ,'CFG','CIT','CMA','CS','EBSB','EGBN','FCCY','FFWM','FHN','FITB','HBMD','HTH','HTLF','HSBC'
        ,'ICBK','JPM','KEY','LBAI','MNSB','NWG','PEBO','PNC','RBNC','RF','SAN','SIVB'
        ,'SSB','STL','TCBI','TFC','UBS','USB','WBS','WFC','ZION']
     
Insurance = ['AJG','AON','MMC','WLTW','AIG','BRK-A','AFL','LNC','MET','MFC','PRU','ALL','AXS','CB',
            'CINF','HMN','LMND','NMIH','PGR','STFC','TRV','WRB','AIZ','FAF','JRVR']

Software = ['ADSK','APPS','AYX','BIGC','CALX','CDNS','CHKP','COIN','COMP','CRM','CTXS','CVLT','DCT','DIDI','DOCU','DT','FICO'
    ,'FSLY','INTU','LSPD','LYFT','MDLA','MSTR','NOW','PAYC','PTC','PUBM','QADA','RIOT','RPD','SAP','SEAC','SHOP',
    'SHSP','SSNC','STMP','TEAM','TTD','UBER','WK','WORK','XELA','XM','YMM','ZI','ADBE','AKAM','APPN','BB','BOX','CRWD',
    'FEYE','FFIV','FIVN','FOUR','GDDY','GSKY','MIME','MSFT','NET','NLOK','OKTA','ORCL','PANW','PATH','PING','PLTR'
    ,'RDWR','S','SPLK','SQ','SWI','TENB','VRSN','ZS']
      
PACKAGED_SOFTWARE = ['MSFT', 'ADBE', 'CRM', 'ORCL', 'INTU', 'SHOP', 'SAP', 'SNOW', 'TEAM', 'UBER', 'ADSK', 'NTES', 'RBLX', 'SNNPS', 'ZM'
            , 'DDOG', 'COIN', 'CDNNS', 'ROP', 'CRWD', 'TWLO', 'ZS', 'U', 'VEEV', 'PLTR', 'MDB', 'ANSS', 'OKTA', 'DOCU', 'APP'
            , 'BILL', 'DIDI', 'PAYC', 'PATH', 'CFLT', 'XM', 'RNG', 'NUAN', 'DT', 'BILI', 'HCP', 'CDAY', 'HOOD', 'NLOK', 'LYFT'
            , 'PTC', 'ASAN', 'S', 'BSY', 'MNDY', 'IOT', 'PCTY', 'OTEX', 'GTLB', 'BKI', 'AUR', 'COUP', 'INFA', 'FICO', 'CTXS'
            , 'AVLR', 'ESTC', 'MCFE']

Semiconductor = ['AMAT', 'AMD', 'ASML', 'AVGO', 'COHU', 'CRUS', 'DQ', 'ENTG', 'INTC',
       'LRCX', 'LSCC', 'MCHP', 'MPWR', 'MRVL', 'MU', 'MXIM', 'NVDA', 'NXPI',
       'ON', 'QCOM', 'QRVO', 'SGH', 'SMTC', 'STM', 'SWKS', 'TSM', 'TXN', 'UMC',
       'XLNX']

MOTOR_VEHICLES = ['ARVL', 'DPRO', 'ELMS', 'F', 'FSR', 'FUV', 'GM', 'GOEV', 'GP', 'HMC', 'HOG', 'HYZN', 'KNDI', 'LCID', 'LEV', 'LI'
                  , 'NIO', 'NIU', 'NKLA', 'PTRA', 'RACE', 'REVG', 'RIDE', 'RIVN', 'SEV', 'SOLO', 'STLA', 'TM', 'TSLA', 'TSP', 'TTM'
                  , 'VLCN', 'XOS', 'XPEV', 'ZEV']
TELECOMMUNICATIONS_EQUIPMENT = ['AAPL', 'QCOM', 'ERIC', 'NOK', 'GRMN', 'UI', 'CIEN' ,'CALX', 'VSAT', 'IDCC', 'COMM', 'INFN', 'AVYA'
                                , 'POLY', 'HLIT', 'AUDC', 'ADTN', 'CLFD', 'INSG', 'SWIR', 'CMTL', 'GILT', 'DZSI', 'AKTS', 'AVNW', 'CAMP'
                                , 'VOXX', 'CRNT', 'PWFL', 'KVHI', 'AIRG', 'WATT', 'PCTI', 'TESS', 'DGLY', 'VISL', 'WTT', 'OCC', 'BKTI'
                                , 'UTSI', 'APWC', 'CLRO', 'JCS', 'UTME', 'SONM', 'BDR']

PHARMACEUTICALS = ['JNJ', 'PFE', 'LLY', 'NVO', 'ABBV', 'NVS', 'MRK', 'AZN', 'BMY', 'SNY', 'GSK', 'TAK', 'RPRX', 'VTRS', 'RGEN', 'GRFS'
                   , 'BHVN', 'ASND', 'EVO', 'OGN', 'LEGN', 'CVAC', 'HCM', 'CERE', 'APLS', 'KRTX', 'IMAB', 'SWTX', 'OPK', 'EQRX', 'DRNA'
                   , 'NKTR', 'IBRX', 'HRMY', 'TPTX', 'EBS', 'ERAS', 'ADCT', 'QTRX', 'AMRX', 'KROS', 'NRIX', 'CRNX', 'ATAI', 'GHRS', 'CNTA'
                  ,'PROC', 'ARCT', 'RETA', 'ARQT', 'DAWN', 'IGMS', 'ZEAL', 'PRAX', 'RPTX']

REAL_ESTATE_INVESTMENT_TRUSTS = ['AMT', 'PLD', 'CCI', 'EQIX', 'PSA', 'SPG', 'DLR', 'SBAC', 'O', 'WELL', 'AVB', 'ARE', 'EQR', 'EXR', 'WY'
                                 , 'INVH', 'MAA', 'DRE', 'LSI', 'SUI', 'ESS', 'VTR', 'PEAK', 'VICI', 'UDR', 'BXP', 'CPT', 'ELS', 'WPC'
                                 , 'IRM', 'KIM', 'AMH', 'MPW', 'REG', 'HST', 'CUBE', 'LAMR', 'NLY', 'REXR', 'CONE', 'GLPI', 'FRT'
                                 , 'STOR', 'EGP', 'FR', 'COLD', 'AIRC', 'NSA', 'NNN', 'STAG']

INTEGRATED_OIL = ['INDO', 'PVL', 'SNMP', 'PRT', 'AMPY', 'REPX', 'FLMN', 'ESTE', 'TELL', 'CNX', 'YPF', 'VNOM', 'DEN', 'CIVI', 'NFG'
                  , 'HESM', 'CHK', 'APA', 'CTRA', 'CVE', 'IMO', 'EC', 'SU', 'E', 'PBR', 'SNP', 'BP', 'EQNR', 'TTE', 'PTR'
                  , 'CVX', 'XOM']

INTERNET_RETAIL = ['AMZN', 'BABA', 'SE', 'JD', 'PDD', 'MELI', 'CPNG', 'LULU', 'EBAY', 'ETSY', 'CHWY', 'W', 'GLBE', 'OZON', 'VIPS'
                   , 'WOOF', 'RVLV', 'NEGG', 'DDL', 'QRTEA', 'QRTEB', 'ACVA', 'OSTK', 'WISH', 'MYTE', 'GIC', 'FLWS', 'TDUP', 'RERE'
                   , 'BZUN', 'AKA', 'CURV', 'REAL', 'MF', 'BOXD', 'GRPN', 'HNST', 'PRTS', 'RENT', 'DLTH', 'DIBS', 'LVLU', 'LITB'
                   , 'IMBI', 'WTRH', 'BQ', 'IPW', 'WNW', 'TC']

BIOTECHNOLOGY = ['AMGN', 'GILD', 'REGN', 'BNTX', 'ILMN', 'VRTX', 'BIIB', 'BGNE', 'SGEN', 'ALNY', 'TECH', 'DNA', 'BMRN', 'TXG', 'INCY'
                 , 'EXAS', 'NVAX', 'NTLA', 'NBIX', 'SRPT', 'MRTX', 'ARWR', 'BPMC', 'CRSP', 'ZLAB', 'FATE', 'EXEL', 'BBIO', 'BEAM'
                 , 'DNLI', 'RARE', 'HALO', 'ARNA', 'VIR', 'ABCM', 'KOD', 'PACB', 'IONS', 'ARVN', 'ITCI', 'ABCL', 'TWST', 'ACAD', 'ALKS']


NFT = [ 'DLPN', 'TKAT', 'ZKIN', 'CIDM', 'HOFV', 'MAT', 'NET', 'TWTR','FNKO', 'PLBY', 'EBay']

sectors=[Bank, Insurance, Software, PACKAGED_SOFTWARE,Semiconductor, MOTOR_VEHICLES, TELECOMMUNICATIONS_EQUIPMENT, PHARMACEUTICALS
         , REAL_ESTATE_INVESTMENT_TRUSTS,INTEGRATED_OIL, INTERNET_RETAIL, BIOTECHNOLOGY, NFT]

sector_name = ['Bank','Insurance','Software','PACKAGED_SOFTWARE','Semiconductor', 'MOTOR_VEHICLES', 'TELECOMMUNICATIONS_EQUIPMENT', 'PHARMACEUTICALS'
         , 'REAL_ESTATE_INVESTMENT_TRUSTS','INTEGRATED_OIL', 'INTERNET_RETAIL', 'BIOTECHNOLOGY', 'NFT']


sum([len(sectors[i]) for i in range(len(sectors))])
# Out:
# 578

# %%
file_directory = '/Users/chakbong/Desktop/Algo Project'

# %%
try:
    import sys
    sys.path.append('/Volumes/SOURCE/Functions')
    sys.path.append('/Volumes/SOURCE')
    from Functions import ytd_csv, txt_days, loop, get_summary, update_dataset, label, filter_text
    print('Imported from USB')
    
except ModuleNotFoundError:
    sys.path.append(file_directory)
    sys.path.append(file_directory + '/Functions')
    from Functions import ytd_csv, txt_days, loop, get_summary, update_dataset, label, filter_text
    print('Imported from ', file_directory)

import update_csv
update_csv.file_directory = file_directory
# Out:
# Imported from  /Users/chakbong/Desktop/Algo Project

# %% [markdown]
# Update All

# %%
import pandas as pd

for l in sector_name:
    Industry=l
    sector_companies = sectors[[i for i in range(len(sector_name)) if sector_name[i]==Industry][0]]
    update=True

    try:
#         print('Trying to import' + ' ' + Industry)
        txt_file = pd.read_csv(file_directory+'/News_Datasets/'+Industry+'_summary_dataset.txt',lineterminator='\n',sep=';')
        try:
            txt_file=txt_file.drop(columns='Unnamed: 0')
        except KeyError:
            pass
        #print('success')

        if update:
            print('updating' + ' ' + Industry)
            dataset = loop(sector_companies, get_summary)
            update_dataset(original_dataset = txt_file, new_dataset = dataset, Industry=Industry)

    except FileNotFoundError:
        print('Creating New Dataset'+' '+Industry)
        dataset = loop(sector_companies, get_summary) 
        dataset.to_csv(file_directory+'/News_Datasets/'+Industry+'_summary_dataset.txt', header=True, index=True, sep=';', mode='a')

for l in sector_name:
    Industry=l
    try: 
        txt_file = pd.read_csv(file_directory+'/News_Datasets/'+Industry+'_summary_dataset.txt',lineterminator='\n',sep=';')
        print('--------------------------------')
        print(l)
        print('from:'+ ' '+txt_file.Date.iloc[0])
        print('to:'+ ' '+txt_file.Date.iloc[-1])
    except Exception:
        print('--------------------------------')
        print(l)
        print("Can't read")
# Out:
# updating Bank
# 0 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMRB: No data found, symbol may be delisted
# 1 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed
# 3 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed
# 4 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed
# 6 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed
# 7 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BOCH: No data found, symbol may be delisted
# 9 %
# ...

# %%
Industry='Bank'
sector_companies = sectors[[i for i in range(len(sector_name)) if sector_name[i]==Industry][0]]
update=False #Update one Sector

# %%
import pandas as pd

try:
    print('Trying to import' + ' ' + Industry)
    txt_file = pd.read_csv(file_directory+'/News_Datasets/'+Industry+'_summary_dataset.txt',lineterminator='\n',sep=';')
    try:
        txt_file=txt_file.drop(columns='Unnamed: 0')
    except KeyError:
        pass
    print('success')
    
    if update:
        print('updating' + ' ' + Industry)
        dataset = loop(sector_companies, get_summary)
        update_dataset(original_dataset = txt_file, new_dataset = dataset, Industry=Industry)

except FileNotFoundError:
    print('Creating New Dataset'+' '+Industry)
    dataset = loop(sector_companies, get_summary) 
    dataset.to_csv(file_directory+'/News_Datasets/'+Industry+'_summary_dataset.txt', header=True, index=True, sep=';', mode='a')

txt_file = pd.read_csv(file_directory+'/News_Datasets/'+Industry+'_summary_dataset.txt',lineterminator='\n',sep=';')

print('from:'+ ' '+txt_file.Date.iloc[0])
print('to:'+ ' '+txt_file.Date.iloc[-1])
# Out:
# Trying to import Bank
# success
# from: 2021-07-06
# to: 2022-11-25

# %%
dataset=txt_file
dataset = dataset.set_index('Date')

m=3
p=0.03
import numpy as np
import pandas as pd
import math
nstock = dataset.shape[1] / 2

for c in range( 1, int(nstock + 1) ):
    y  = dataset.iloc[0: ,  (2*(c-1)) : (2*c-1)]   # close

change_m = [(y.iloc[i+j].values[0]-y.iloc[j].values[0])/y.iloc[j].values[0] for i in range(1,m+1) for j in range(len(y)-m)]
change_m_no_nan = [change_m[i] for i in range(len(change_m)) if not np.isnan(change_m[i])]

print(len(change_m_no_nan))
print(np.quantile(change_m_no_nan, [0.1,0.5,0.9]))
pd.DataFrame(change_m_no_nan).plot(kind='hist', color = 'hotpink')
len([i for i in change_m_no_nan if i>p])/len(change_m_no_nan)

np.var(y )
# Out:
# 60
# [-0.0304731  -0.00476391  0.0190167 ]
# Close.65    0.30456
# dtype: float64

# %%
m=3 #<--
p=0.03 #<--

df = label(txt_file,m=m, p=p)
df.dropna(subset = ["news"], inplace = True)
df.dropna(subset = ["label"], inplace = True)

from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
from keras import layers
from keras import regularizers
from keras import backend as K
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

df.iloc[:,0] = df.iloc[:,0].apply(lambda x: x.lower())
df.iloc[:,0] = df.iloc[:,0].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

y = df.iloc[:,1]
X = df.iloc[:,0]

max_features = 2500
tokenizer_original = Tokenizer(num_words=max_features, split=' ')
tokenizer_original.fit_on_texts(X.values)
X_original = tokenizer_original.texts_to_sequences(X.values)
X_original = pad_sequences(X_original)

tokenizer = Tokenizer(num_words=max_features, split=' ')
filtered_text=filter_text(X)
tokenizer.fit_on_texts(filtered_text)
X=tokenizer.texts_to_sequences(filtered_text)
X=pad_sequences(X)

y = pd.get_dummies(df.iloc[:,1]).values

# %%
print('After NLP ', X.shape)
print('Before NLP ', X_original.shape)
print(y.shape)
# Out:
# After NLP  (7584, 702)
# Before NLP  (7584, 1080)
# (7584, 3)

# %%
# #SMOTE
# from imblearn.over_sampling import SMOTE
# # transform the dataset
# # define pipeline
# over = SMOTE()
# under = RandomUnderSampler()
# steps = [('o', over), ('u', under)]
# pipeline = Pipeline(steps=steps)
# # transform the dataset
# X_smote, y_smote = pipeline.fit_resample(X, y)
# print(X_smote.shape)
# print(y_smote.shape)

# %%
import numpy as np

min_loc = [i for i in range(len(y)) if y[i][1]!=1]
maj_loc = [i for i in range(len(y)) if y[i][1]==1]

X_dupmin = X
y_dupmin = y

for m in range(1):

    for i in range(len(min_loc)):
        X_dupmin = np.insert(X_dupmin,len(X_dupmin),X_dupmin[min_loc[i]], axis=0)
        y_dupmin = np.insert(y_dupmin,len(y_dupmin),y_dupmin[min_loc[i]], axis=0)

# %%
len(X_dupmin)
# Out:
# 9496

# %%
# Labelling Dist
df['label'].plot(kind='hist')

# pd.DataFrame([np.where(y_smote[i]==1)[0][0]-1 for i in range(len(y_smote)) ]).plot(kind='hist')
pd.DataFrame([np.where(y_dupmin[i]==1)[0][0]-1 for i in range(len(y_dupmin)) ]).plot(kind='hist', color = 'purple')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
test_size=0.1
epochs=20
# tf.random.set_seed(0) ---add
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size,  shuffle = True)#random_state = 42)

#Delete overlapping days m
y_test = y_test.copy()[m:]
X_test = X_test.copy()[m:]

model = Sequential()
model.add(layers.Embedding(max_features,40)) #40###
model.add(layers.Bidirectional(layers.LSTM(20,dropout=0.1)))  #Modify Layer Here 20
model.add(layers.Dense(y_train.shape[1],activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
batch_size = 32
#model.fit(X_train, y_train, epochs = epochs, batch_size=batch_size, shuffle = True)
print(y_train.shape)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, None, 40)          100000
#
#  bidirectional (Bidirectiona  (None, 40)               9760
#  l)
#
#  dense (Dense)               (None, 3)                 123
#
# ...
# Total params: 109,883
# Trainable params: 109,883
# Non-trainable params: 0
# _________________________________________________________________
# (6825, 3)

# %%
test_size=0.1
epochs=20
# tf.random.set_seed(0) ---add
X_train, X_test, y_train, y_test = train_test_split(X_dupmin, y_dupmin, test_size = test_size,  shuffle = True)#random_state = 42)

#Delete overlapping days m
y_test = y_test.copy()[m:]
X_test = X_test.copy()[m:]

model = Sequential()
model.add(layers.Embedding(max_features, 40, input_length=X.shape[1])) #40###
model.add(layers.Bidirectional(layers.LSTM(20,dropout=0.6)))  #Modify Layer Here 20
model.add(layers.Dense(y_train.shape[1],activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 32
model.fit(X_train, y_train, epochs = epochs, batch_size=batch_size, shuffle = True)#, verbose = 2)
# model.summary()
# Out:
# Epoch 1/20
# 268/268 [==============================] - 70s 249ms/step - loss: 0.9540 - accuracy: 0.5941
# Epoch 2/20
# 268/268 [==============================] - 66s 248ms/step - loss: 0.8752 - accuracy: 0.6061
# Epoch 3/20
# 268/268 [==============================] - 75s 281ms/step - loss: 0.7729 - accuracy: 0.6603
# Epoch 4/20
# 268/268 [==============================] - 66s 245ms/step - loss: 0.6803 - accuracy: 0.7126
# Epoch 5/20
# 268/268 [==============================] - 69s 257ms/step - loss: 0.6201 - accuracy: 0.7389
# Epoch 6/20
# 268/268 [==============================] - 67s 249ms/step - loss: 0.5749 - accuracy: 0.7550
# Epoch 7/20
# 268/268 [==============================] - 67s 251ms/step - loss: 0.5424 - accuracy: 0.7760
# Epoch 8/20
# 268/268 [==============================] - 63s 236ms/step - loss: 0.5139 - accuracy: 0.7889
# Epoch 9/20
# 268/268 [==============================] - 65s 241ms/step - loss: 0.4749 - accuracy: 0.8007
# Epoch 10/20
# ...

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
y_hat = model.predict([X_test])

y_pred=[np.where(y_hat[i] == max(y_hat[i]))[0][0] for i in range(len(y_hat))]

y_true=[np.where(y_test[i]==1)[0][0] for i in range(len(y_test))]

cm = confusion_matrix(y_true, y_pred)

confusion = pd.DataFrame([[np.nan,np.nan,np.nan]], columns=['Sell','Hold','Buy'], index = ['Sell','Hold','Buy'])
confusion.iloc[:,:]=cm
confusion = confusion.style.set_caption('prediction')
print(classification_report(y_true, y_pred))
print('Buy:', ' ', confusion.data.Buy[2]/(confusion.data.Buy[0]+confusion.data.Buy[2])*100, '%')
print('Sell:', ' ', confusion.data.Sell[0]/(confusion.data.Sell[0]+confusion.data.Sell[2])*100, '%')
confusion
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.68       199
#            1       0.86      0.76      0.80       558
#            2       0.70      0.79      0.74       193
#
#     accuracy                           0.76       950
#    macro avg       0.73      0.76      0.74       950
# weighted avg       0.78      0.76      0.77       950
#
# Buy:   93.29268292682927 %
# Sell:   93.67088607594937 %
# <style  type="text/css" >
# </style><table id="T_40ea0_" ><caption>prediction</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sell</th>        <th class="col_heading level0 col1" >Hold</th>        <th class="col_heading level0 col2" >Buy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40ea0_level0_row0" class="row_heading level0 row0" >Sell</th>
#                         <td id="T_40ea0_row0_col0" class="data row0 col0" >148</td>
# ...

# %%
#model.save('News_Model')

# %%
selc_criteria = 0.9

reference = pd.DataFrame([np.repeat(np.nan,3)], columns=['true', 'Prediction', '%'], index=np.linspace(1,len(y_hat),len(y_hat)))
percentage = [max(y_hat[i]) for i in range(len(y_hat))]

reference.Prediction = y_pred
reference.true = y_true
reference['%'] = percentage

# print(reference)
y_pred_selected = [y_pred[i] for i in range(len(reference)) if (percentage[i]>selc_criteria)]
y_true_selected = [y_true[i] for i in range(len(reference)) if (percentage[i]>selc_criteria)]

cm_selected = confusion_matrix(y_true_selected, y_pred_selected)
confusion_selected = pd.DataFrame([[np.nan,np.nan,np.nan]], columns=['Sell','Hold','Buy'], index = ['Sell','Hold','Buy'])
confusion_selected.iloc[:,:]=cm_selected
confusion_selected = confusion_selected.style.set_caption('prediction (selected)')

from sklearn.metrics import classification_report
print(classification_report(y_true_selected, y_pred_selected))
print('Buy:', ' ',confusion_selected.data.Buy[2]/(confusion_selected.data.Buy[0]+confusion_selected.data.Buy[2])*100,'%')
print('Sell:', ' ',confusion_selected.data.Sell[0]/(confusion_selected.data.Sell[0]+confusion_selected.data.Sell[2])*100,'%')
confusion_selected
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85        90
#            1       0.95      0.88      0.92       344
#            2       0.80      0.91      0.85        88
#
#     accuracy                           0.89       522
#    macro avg       0.85      0.90      0.87       522
# weighted avg       0.90      0.89      0.89       522
#
# Buy:   100.0 %
# Sell:   100.0 %
# <style  type="text/css" >
# </style><table id="T_7ca10_" ><caption>prediction (selected)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sell</th>        <th class="col_heading level0 col1" >Hold</th>        <th class="col_heading level0 col2" >Buy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7ca10_level0_row0" class="row_heading level0 row0" >Sell</th>
#                         <td id="T_7ca10_row0_col0" class="data row0 col0" >82</td>
# ...

# %%
# # pd.set_option('display.max_rows', 5000)
# # pd.set_option('display.max_columns', 500)
# # reference
# print(y_hat[14])
# reference
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 500)

Bank = ['AMRB','BAC','BK','BMO','BNS','BOCH','BXS','CBAN','CM','COLB','DB','FRC','FVCB','HDB','INDB'
        ,'LYG','MTB','NCBS','OZK','RY','SBNY','TD','UCBI','ALTA','BCBP','BCS','BSAC','BSBR','C'
        ,'CFG','CIT','CMA','CS','EBSB','EGBN','FCCY','FFWM','FHN','FITB','HBMD','HTH','HTLF','HSBC'
        ,'ICBK','JPM','KEY','LBAI','MNSB','NWG','PEBO','PNC','RBNC','RF','SAN','SIVB'
        ,'SSB','STL','TCBI','TFC','UBS','USB','WBS','WFC','ZION']

# %%
ticker = 'hsbc'
test_dataset = loop([ticker], get_summary) 
# test_dataset
# Out:
# 0 %
# 361641b2f2msh6a1b4170174acf0p13d27djsnde179ff3425e gged
# [*********************100%***********************]  1 of 1 completed

# %%
test_dataset
# Out:
#                 Close                                       hsbc_Summary
# Date
# 2022-10-26  25.910000  Here at Zacks, our focus is on the proven Zack...
# 2022-10-27  26.040001  Denmark’s largest bank said it expects to pay ...
# 2022-10-28  25.930000  HSBC vs. NABZY: Which Stock Is the Better Valu...
# 2022-10-31  25.910000  NEW YORK, October 31, 2022--HSBC U.S. Private ...
# 2022-11-01  26.440001  Insiders who bought HSBC Holdings plc ( LON:HS...
# 2022-11-02  26.100000  India's digital rupee pilot payment scheme wil...
# 2022-11-03  25.889999  In this article, we will take a look at 16 of ...
# 2022-11-04  28.160000  Ping An Insurance Group, HSBC's biggest shareh...
# 2022-11-07  27.580000  Should investors be excited or worried when a ...
# 2022-11-08  27.730000  Business leaders are pushing for specific acti...
# 2022-11-09  27.139999                                                NaN
# 2022-11-10  27.850000                                                NaN
# ...

# %%
# Test
# ticker = 'RY'
# test_dataset = loop([ticker], get_summary)


m=3 #<--
p=0.03 #<--
#########################
#########################

label_backtest = label(test_dataset,m=m, p=p,set_index=False)
label_backtest.index = test_dataset.index

backtest_dataset = pd.concat([label_backtest['label'],test_dataset],1)

reference_backtest = pd.DataFrame([np.repeat(np.nan,5)], columns=['Sell', "Hold", "Buy", 'Prediction','News'], index=backtest_dataset.index)

news_backtest = backtest_dataset.iloc[:,2]
# news=['''However, an energy price shock amid a central bank pivot focused on inflation could further dampen investor sentiment.''']

for i in range(len(news_backtest)):
    news=news_backtest[i]

    try:
        if np.isnan(news):
            pass

    except TypeError:
        test=df.iloc[:,0]
        test = test.append(pd.Series(news))
        tokenizer = Tokenizer(num_words=max_features, split=' ')
        filtered_test=filter_text(test)
        tokenizer.fit_on_texts(filtered_test)
        news_nlp=tokenizer.texts_to_sequences(filtered_test)
        news_nlp=pad_sequences(news_nlp)
        news_nlp=news_nlp[-1]#hihihiihihihi

        pred=model.predict(news_nlp.reshape(1,-1))

        pred = pred[0].tolist()
        pred.append([i for i in range(len(pred)) if pred[i]==max(pred)][0])
        pred.append(news[0])
        reference_backtest.iloc[i,:] = pred
# reference_backtest
#########################
#########Report##########
#########################
cash_initial = 0
stock_price = test_dataset['Close']

cash = pd.DataFrame(np.repeat(np.nan, len(backtest_dataset)))
quantity = pd.DataFrame(np.repeat(np.nan, len(backtest_dataset)))
value = pd.DataFrame(np.repeat(np.nan, len(backtest_dataset)))
action = pd.DataFrame(np.repeat(np.nan, len(backtest_dataset)))
pnl = pd.DataFrame(np.repeat(np.nan, len(backtest_dataset)))

price_long = []
price_short = []
# action.index = test_dataset.index

for j in  [i for i in range(len(test_dataset)) if reference_backtest['Prediction'][i] == 0]:
    action.iloc[j,0]='Short'

for j in [i for i in range(len(test_dataset)) if reference_backtest['Prediction'][i] == 1]:
    action.iloc[j,0]='Within'

for j in [i for i in range(len(test_dataset)) if reference_backtest['Prediction'][i] == 2]:
    action.iloc[j,0]='Long'

for j in [i for i in range(len(test_dataset)) if np.isnan(reference_backtest['Prediction'][i])]:
    action.iloc[j,0]='No Signal'

#initialize
quantity_per_trade = 1

if action.iloc[0,0] == 'Short':
    cash.iloc[0] = quantity_per_trade*stock_price[0]
    quantity.iloc[0] = -1*quantity_per_trade

if action.iloc[0,0] == 'Within' or action.iloc[0,0] == 'No Signal':
    cash.iloc[0] = cash_initial
    quantity.iloc[0] = 0

if action.iloc[0,0] == 'Long':
    cash.iloc[0] = -quantity_per_trade*stock_price[0]
    quantity.iloc[0] = 1*quantity_per_trade


value.iloc[0] = stock_price[0]*quantity.iloc[0]

############################################
#Modify Buy Sell Strategy Here##############
############################################

#Basic
for i in range(0, len(test_dataset)-1, 1):

    if action.iloc[i+1,0] == 'Short':
        cash.iloc[i+1] = quantity_per_trade*stock_price[i+1] + cash.iloc[i]
        quantity.iloc[i+1] = -1*quantity_per_trade + quantity.iloc[i]
        price_short.append(stock_price[i+1])

    if action.iloc[i+1,0] == 'Within' or action.iloc[i+1,0] =='No Signal':
        cash.iloc[i+1] = cash.iloc[i]
        quantity.iloc[i+1] = quantity.iloc[i]

    if action.iloc[i+1,0] == 'Long':
        cash.iloc[i+1] = -quantity_per_trade*stock_price[i+1] + cash.iloc[i]
        quantity.iloc[i+1] = +quantity_per_trade*1 + quantity.iloc[i]
        price_long.append(stock_price[i+1])

for i in range(len(test_dataset)):        
    value.iloc[i] = stock_price[i]*quantity.iloc[i]
    pnl.iloc[i] = value.iloc[i] + cash.iloc[i]

# # #Clear All
# for i in range(0, len(test_dataset)-1, 1):

#     if action.iloc[i+1,0] == 'Short':
#         cash.iloc[i+1] = quantity_per_trade*stock_price[i+1] + cash.iloc[i] + stock_price[i+1]*quantity.iloc[i]
#         quantity.iloc[i+1] = -1*quantity_per_trade
#         price_short.append(stock_price[i+1])

#     if action.iloc[i+1,0] == 'Within' or action.iloc[i+1,0] =='No Signal':
#         cash.iloc[i+1] = cash.iloc[i]
#         quantity.iloc[i+1] = quantity.iloc[i]

#     if action.iloc[i+1,0] == 'Long':
#         cash.iloc[i+1] = -quantity_per_trade*stock_price[i+1] + cash.iloc[i] + stock_price[i+1]*quantity.iloc[i]
#         quantity.iloc[i+1] = +quantity_per_trade*1
#         price_long.append(stock_price[i+1])

# for i in range(len(test_dataset)):        
#     value.iloc[i] = stock_price[i]*quantity.iloc[i]
#     pnl.iloc[i] = value.iloc[i] + cash.iloc[i]
############################################
############################################
############################################
value.index = test_dataset.index
value.columns = ['Value']
cash.index = test_dataset.index
cash.columns = ['Cash']
action.index = test_dataset.index
action.columns = ['Action']
quantity.index = test_dataset.index
quantity.columns = ['Quantity']
pnl.index = test_dataset.index
pnl.columns = ['P/L']

backtest_result = pd.concat([backtest_dataset, reference_backtest.iloc[:,:3], action, quantity, cash, value, pnl], 1)
backtest_result['P/L'].plot()
print('Correlation. ', pd.concat([backtest_result['Close'],backtest_result['P/L']], 1).corr())
print('----------------------------------')
print('Prediction Correlation. ', pd.concat([backtest_result['label'],reference_backtest['Prediction']], 1).corr())
print(np.mean(price_long), np.mean(price_short))

# backtest_result.to_csv('~/Desktop/basic')
# backtest_result.to_excel('~/Desktop/Algo Project/Banking_Live_Test_Results/'+ticker+'.xls')
backtest_result
# Out:
# Correlation.            Close       P/L
# Close  1.000000  0.988103
# P/L    0.988103  1.000000
# Prediction Correlation.               label  Prediction
# label       1.0000     -0.0533
# Prediction -0.0533      1.0000
# 26.650000254313152 28.8149995803833
#             label      Close  \
# Date
# 2022-10-26    0.0  25.910000
# 2022-10-27    0.0  26.040001
# 2022-10-28    0.0  25.930000
# 2022-10-31    0.0  25.910000
# 2022-11-01    0.0  26.440001
# 2022-11-02    1.0  26.100000
# 2022-11-03    1.0  25.889999
# 2022-11-04    0.0  28.160000
# 2022-11-07    0.0  27.580000
# 2022-11-08    0.0  27.730000
# 2022-11-09    1.0  27.139999
# 2022-11-10    0.0  27.850000
# 2022-11-11    0.0  28.049999
# 2022-11-14    0.0  28.190001
# 2022-11-15    0.0  28.250000
# 2022-11-16    0.0  28.270000
# 2022-11-17    0.0  28.580000
# 2022-11-18    0.0  28.549999
# 2022-11-21    0.0  28.750000
# 2022-11-22    NaN  28.950001
# 2022-11-23    NaN  29.469999
# 2022-11-25    NaN  29.719999
#
# ...

# %%
def read_news(date):
    return(backtest_result.iloc[np.where(backtest_result.index == date)[0][0],2])

read_news('2022-10-26')
# Out:
# 'Here at Zacks, our focus is on the proven Zacks Rank system, which emphasizes earnings estimates and estimate revisions to find great stocks. Nevertheless, we are always paying attention to the latest value, growth, and momentum trends to underscore strong picks.Companies in The News Are: CBRE, HSBC, KO, DFSRise in NII and fee income, solid loan demand, decline in provisions and higher interest rates support ICICI Bank\'s (IBN) fiscal Q2 earnings.LONDON/SINGAPORE (Reuters) -Georges Elhedery\'s appointment as HSBC\'s chief financial officer caps a journey that\'s taken him from war-torn Lebanon to frontrunner for the top job at Europe\'s biggest bank.  Known at HSBC for his strategic vision more than for his accounting skills, Elhedery has climbed the ranks of HSBC’s investment bank since joining in 2005.  "It was a surprise to us,” said Hugh Young, Asia chairman of Aberdeen Standard Investments, one of HSBC\'s top 25 shareholders.Profit before tax grew by 27% to $298 million over th
# ...
